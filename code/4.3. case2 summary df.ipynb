# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##

# %%
N1,N2
# Out:
# (1181, 1444)

# %%
D_p, D_n
# Out:
# (1313, 4687)

# %%
#c_01 = 2.3
D_n = 4687
D_p = 1313

# %%
N_list1 = [ [0.1, 0.8], [0.2,0.5] , [0.6, 1.1]  , [0.7, 1] , [0.8, 1.2], [0.8, 1.4], [0.9,1.1] , [1.1,1.3], [1.5, 1.8] ]
list_ = []
for N1,N2 in N_list1:
    N1_ = int(D_p * N1)
    N2_ = int(D_p * N2)
    list_.append([N1_,N2_])
list_
# Out:
# [[131, 1050],
#  [262, 656],
#  [787, 1444],
#  [919, 1313],
#  [1050, 1575],
#  [1050, 1838],
#  [1181, 1444],
#  [1444, 1706],
#  [1969, 2363]]

# %%
for i in range(1,20):
    print(i/10, int(D_p * i / 10))
# Out:
# 0.1 131
# 0.2 262
# 0.3 393
# 0.4 525
# 0.5 656
# 0.6 787
# 0.7 919
# 0.8 1050
# 0.9 1181
# 1.0 1313
# 1.1 1444
# 1.2 1575
# 1.3 1706
# 1.4 1838
# 1.5 1969
# 1.6 2100
# 1.7 2232
# 1.8 2363
# 1.9 2494

# %%
#ondemand
p_list = [2,4,6,8,10]
#N_list = [ [1050,1575], [1050,1838] , [1181,1444] , [131,1050] , [1969,2363] , [262,656]  ]

N_list = [ [131,1050], [1050,1575], [1050,1838] , [1181,1444]  ]

# [0.1, 0.8], [0.2,0.5], [0.8, 1.2], [0.8, 1.4], [1, 1.1], [1.5, 1.8]

# requires [0.6, 1.1] , [0.7, 1] , [0.9,1.4] , [1, 1.2] , [1.1,1.3]


list_N = []
list_p = []

list_c = []
list_per=[]
list_pr=[]
list_re=[]
list_f1s=[]
list_aucs = []
list_mccs = []
list_gmeans = []
list_bound = []



for (N1, N2) in N_list:
    list_N.append(['ondemand',N1,N2])
    list_cost = []
    list_precision = []
    list_recall = []
    list_f1 = []
    list_auc = []
    list_mcc = []
    list_gmean = []



    for p in p_list:

        df = pd.read_csv('result/case2/result_ondemand_'+str(N1) + '_' + str(N2)+'_'+str(p)+'.csv')

        cost_ = []
        for i in range(len(df)):
            fn = int(df.list_conmat[i][1:-1].split(',')[1])
            fp = int(df.list_conmat[i][1:-1].split(',')[2])

            cost = fn*c_01 +fp
            cost_.append(cost)

        list_cost.append(cost_)
        list_precision.append(df.list_precision.values)
        list_recall.append(df.list_recall.values)
        list_f1.append(df.list_f1.values)
        list_auc.append(df.list_auc.values)
        list_mcc.append(df.list_mcc.values)
        list_gmean.append(df.list_gmean.values)


    maximum = D_p * c_01 + D_n
    minimum = (D_p - N2) *c_01
    if minimum < 0:
        minimum =0

    cost_mean = np.round(np.mean(list_cost),3)
    cost_std = np.round(np.std(list_cost),3)


    precision_mean = str(np.round(np.mean(list_precision),2))
    precision_std = str(np.round(np.std(list_precision),2))

    recall_mean = str(np.round(np.mean(list_recall),2))
    recall_std = str(np.round(np.std(list_recall),2))

    f1_mean = str(np.round(np.mean(list_f1),2))
    f1_std = str(np.round(np.std(list_f1),2))

    auc_mean = str(np.round(np.mean(list_auc),2))
    auc_std = str(np.round(np.std(list_auc),2))

    mcc_mean = str(np.round(np.mean(list_mcc),2))
    mcc_std = str(np.round(np.std(list_mcc),2))

    gmean_mean = str(np.round(np.mean(list_gmean),2))
    gmean_std = str(np.round(np.std(list_gmean),2))

    cost_mean = str(cost_mean)
    cost_std = str(cost_std)

    list_c.append(cost_mean +'±'+ cost_std)
    list_pr.append(precision_mean +'±'+ precision_std)
    list_re.append(recall_mean +'±'+ recall_std)
    list_f1s.append(f1_mean +'±'+f1_std)
    list_aucs.append(auc_mean+'±'+ auc_std)
    list_mccs.append(mcc_mean+'±'+ mcc_std)
    list_gmeans.append(gmean_mean+'±'+gmean_std)



dict_ondemand = {'N': list_N, 'cost': list_c, 'precision': list_pr, 'recall': list_re, 'f1': list_f1s, 'auc':list_aucs, 'mcc':list_mccs, 'gmeans':list_gmeans}
df_ondemand = pd.DataFrame(dict_ondemand)

# %%
#CS
p_list = [2,4,6,8,10]
N_list = [ [131,1050], [1050,1575], [1050,1838] , [1181,1444]  ]

list_N = []
list_p = []

list_c = []
list_per=[]
list_pr=[]
list_re=[]
list_f1s=[]
list_aucs = []
list_mccs = []
list_gmeans = []
list_bound = []



for (N1, N2) in N_list:
    list_N.append(['cs',N1,N2])
    list_cost = []
    list_precision = []
    list_recall = []
    list_f1 = []
    list_auc = []
    list_mcc = []
    list_gmean = []



    for p in p_list:

        df = pd.read_csv('result/case2/result_cs_'+str(N1) + '_' + str(N2)+'.csv')

        cost_ = []
        for i in range(len(df)):
            fn = int(df.con_mat[i][1:-1].split(',')[1])
            fp = int(df.con_mat[i][1:-1].split(',')[2])

            cost = fn*c_01+fp
            cost_.append(cost)

        list_cost.append(cost_)
        list_precision.append(df.list_precision.values)
        list_recall.append(df.list_recall.values)
        list_f1.append(df.list_f1.values)
        list_auc.append(df.list_auc.values)
        list_mcc.append(df.list_mcc.values)
        list_gmean.append(df.list_gmean.values)


    maximum = D_p * c_01 + D_n
    minimum = (D_p - N2) *c_01
    if minimum < 0:
        minimum =0

    cost_mean = np.round(np.mean(list_cost),3)
    cost_std = np.round(np.std(list_cost),3)


    precision_mean = str(np.round(np.mean(list_precision),2))
    precision_std = str(np.round(np.std(list_precision),2))

    recall_mean = str(np.round(np.mean(list_recall),2))
    recall_std = str(np.round(np.std(list_recall),2))

    f1_mean = str(np.round(np.mean(list_f1),2))
    f1_std = str(np.round(np.std(list_f1),2))

    auc_mean = str(np.round(np.mean(list_auc),2))
    auc_std = str(np.round(np.std(list_auc),2))

    mcc_mean = str(np.round(np.mean(list_mcc),2))
    mcc_std = str(np.round(np.std(list_mcc),2))

    gmean_mean = str(np.round(np.mean(list_gmean),2))
    gmean_std = str(np.round(np.std(list_gmean),2))

    cost_mean = str(cost_mean)
    cost_std = str(cost_std)

    list_c.append(cost_mean +'±'+ cost_std)
    list_pr.append(precision_mean +'±'+ precision_std)
    list_re.append(recall_mean +'±'+ recall_std)
    list_f1s.append(f1_mean +'±'+f1_std)
    list_aucs.append(auc_mean+'±'+ auc_std)
    list_mccs.append(mcc_mean+'±'+ mcc_std)
    list_gmeans.append(gmean_mean+'±'+gmean_std)



dict_cs = {'N': list_N, 'cost': list_c, 'precision': list_pr, 'recall': list_re, 'f1': list_f1s, 'auc':list_aucs, 'mcc':list_mccs, 'gmeans':list_gmeans}
df_cs = pd.DataFrame(dict_cs)

# %%
#nn
p_list = [2,4,6,8,10]
N_list = [ [1050,1575], [1050,1838] , [1181,1444] , [131,1050] ]


list_N = []
list_p = []

list_c = []
list_per=[]
list_pr=[]
list_re=[]
list_f1s=[]
list_aucs = []
list_mccs = []
list_gmeans = []
list_bound = []



for (N1, N2) in N_list:
    list_N.append(['nn',N1,N2])
    list_cost = []
    list_precision = []
    list_recall = []
    list_f1 = []
    list_auc = []
    list_mcc = []
    list_gmean = []



    for p in p_list:

        df = pd.read_csv('result/case2/result_nn_'+str(N1) + '_' + str(N2)+'.csv')

        cost_ = []
        for i in range(len(df)):
            fn = int(df.con_mat[i][1:-1].split(',')[1])
            fp = int(df.con_mat[i][1:-1].split(',')[2])

            cost = fn*c_01 +fp
            cost_.append(cost)

        list_cost.append(cost_)
        list_precision.append(df.list_precision.values)
        list_recall.append(df.list_recall.values)
        list_f1.append(df.list_f1.values)
        list_auc.append(df.list_auc.values)
        list_mcc.append(df.list_mcc.values)
        list_gmean.append(df.list_gmean.values)



    cost_mean = np.round(np.mean(list_cost),3)
    cost_std = np.round(np.std(list_cost),3)



    precision_mean = str(np.round(np.mean(list_precision),2))
    precision_std = str(np.round(np.std(list_precision),2))

    recall_mean = str(np.round(np.mean(list_recall),2))
    recall_std = str(np.round(np.std(list_recall),2))

    f1_mean = str(np.round(np.mean(list_f1),2))
    f1_std = str(np.round(np.std(list_f1),2))

    auc_mean = str(np.round(np.mean(list_auc),2))
    auc_std = str(np.round(np.std(list_auc),2))

    mcc_mean = str(np.round(np.mean(list_mcc),2))
    mcc_std = str(np.round(np.std(list_mcc),2))

    gmean_mean = str(np.round(np.mean(list_gmean),2))
    gmean_std = str(np.round(np.std(list_gmean),2))

    cost_mean = str(cost_mean)
    cost_std = str(cost_std)


    list_c.append(cost_mean +'±'+ cost_std)
    list_pr.append(precision_mean +'±'+ precision_std)
    list_re.append(recall_mean +'±'+ recall_std)
    list_f1s.append(f1_mean +'±'+f1_std)
    list_aucs.append(auc_mean+'±'+ auc_std)
    list_mccs.append(mcc_mean+'±'+ mcc_std)
    list_gmeans.append(gmean_mean+'±'+gmean_std)


dict_nn = {'N': list_N,'cost': list_c,'precision': list_pr, 'recall': list_re, 'f1': list_f1s, 'auc':list_aucs, 'mcc':list_mccs, 'gmeans':list_gmeans}
df_nn = pd.DataFrame(dict_nn)

# %%
#spo
p_list = [2,4,6,8,10]
N_list = [ [131,1050], [1050,1575], [1050,1838] , [1181,1444]  ]


list_N = []
list_p = []

list_c = []
list_per=[]
list_pr=[]
list_re=[]
list_f1s=[]
list_aucs = []
list_mccs = []
list_gmeans = []
list_bound = []



for (N1, N2) in N_list:
    list_N.append(['spo',N1,N2])
    list_cost = []
    list_precision = []
    list_recall = []
    list_f1 = []
    list_auc = []
    list_mcc = []
    list_gmean = []



    for p in p_list:

        df = pd.read_csv('result/case2/result_spo_'+str(N1) + '_' + str(N2)+'.csv')

        cost_ = []
        for i in range(len(df)):
            fn = int(df.con_mat[i][1:-1].split(',')[1])
            fp = int(df.con_mat[i][1:-1].split(',')[2])

            cost = fn*c_01 +fp
            cost_.append(cost)

        list_cost.append(cost_)
        list_precision.append(df.list_precision.values)
        list_recall.append(df.list_recall.values)
        list_f1.append(df.list_f1.values)
        list_auc.append(df.list_auc.values)
        list_mcc.append(df.list_mcc.values)
        list_gmean.append(df.list_gmean.values)




    cost_mean = np.round(np.mean(list_cost),3)
    cost_std = np.round(np.std(list_cost),3)


    precision_mean = str(np.round(np.mean(list_precision),2))
    precision_std = str(np.round(np.std(list_precision),2))

    recall_mean = str(np.round(np.mean(list_recall),2))
    recall_std = str(np.round(np.std(list_recall),2))

    f1_mean = str(np.round(np.mean(list_f1),2))
    f1_std = str(np.round(np.std(list_f1),2))

    auc_mean = str(np.round(np.mean(list_auc),2))
    auc_std = str(np.round(np.std(list_auc),2))

    mcc_mean = str(np.round(np.mean(list_mcc),2))
    mcc_std = str(np.round(np.std(list_mcc),2))

    gmean_mean = str(np.round(np.mean(list_gmean),2))
    gmean_std = str(np.round(np.std(list_gmean),2))

    cost_mean = str(cost_mean)
    cost_std = str(cost_std)

   
    list_c.append(cost_mean +'±'+ cost_std)
    list_pr.append(precision_mean +'±'+ precision_std)
    list_re.append(recall_mean +'±'+ recall_std)
    list_f1s.append(f1_mean +'±'+f1_std)
    list_aucs.append(auc_mean+'±'+ auc_std)
    list_mccs.append(mcc_mean+'±'+ mcc_std)
    list_gmeans.append(gmean_mean+'±'+gmean_std)

dict_spo = {'N': list_N, 'cost': list_c,  'precision': list_pr, 'recall': list_re, 'f1': list_f1s, 'auc':list_aucs, 'mcc':list_mccs, 'gmeans':list_gmeans}
df_spo = pd.DataFrame(dict_spo)

# %%
methods = ['nn','cs','spo','ondemand']


df = pd.DataFrame()

for i in range(4):
    for method in methods:

        df_ = globals()['df_' + method]

        column = df_.T.columns[i]
        df_T = df_.T

        df = df.append(df_T.pop(column))

col =df_ondemand.columns.tolist()
df = df[col]
df.to_csv('result/2.DCCC result.csv')
df
# Out:
#                         N            cost  precision     recall         f1  \
# 0        [nn, 1050, 1575]      2253.6±0.0   0.52±0.0   0.52±0.0   0.52±0.0
# 0         [cs, 131, 1050]    2255.56±18.3   0.58±0.0   0.47±0.0   0.52±0.0
# 0        [spo, 131, 1050]      3433.2±0.0   0.24±0.0   0.02±0.0   0.04±0.0
# 0   [ondemand, 131, 1050]  2231.384±6.683   0.59±0.0   0.47±0.0   0.52±0.0
# 1        [nn, 1050, 1838]      2250.0±0.0   0.52±0.0   0.52±0.0   0.52±0.0
# 1        [cs, 1050, 1575]   2221.2±15.609   0.53±0.0   0.53±0.0   0.53±0.0
# 1       [spo, 1050, 1575]    3320.8±507.6  0.29±0.11  0.25±0.13  0.27±0.12
# 1  [ondemand, 1050, 1575]  2155.012±7.524  0.53±0.01  0.56±0.02   0.54±0.0
# 2        [nn, 1181, 1444]      2250.0±0.0   0.52±0.0   0.52±0.0   0.52±0.0
# 2        [cs, 1050, 1838]   2221.2±15.609   0.53±0.0   0.53±0.0   0.53±0.0
# 2       [spo, 1050, 1838]      3574.6±0.0   0.24±0.0   0.19±0.0   0.21±0.0
# 2  [ondemand, 1050, 1838]  2153.846±5.761  0.54±0.02  0.55±0.02   0.54±0.0
# 3         [nn, 131, 1050]      2249.8±0.0   0.59±0.0   0.47±0.0   0.52±0.0
# 3        [cs, 1181, 1444]   2221.2±21.359   0.53±0.0   0.53±0.0   0.53±0.0
# 3       [spo, 1181, 1444]    3625.68±1.44   0.23±0.0    0.2±0.0   0.22±0.0
# 3  [ondemand, 1181, 1444]   2168.44±10.41  0.53±0.01  0.55±0.01   0.54±0.0
#
#          auc        mcc     gmeans
# 0    0.7±0.0   0.39±0.0   0.67±0.0
# 0   0.69±0.0  0.41±0.01   0.65±0.0
# 0    0.5±0.0   0.01±0.0   0.15±0.0
# 0   0.31±0.0   0.41±0.0   0.65±0.0
# 1    0.7±0.0   0.39±0.0   0.67±0.0
# 1    0.7±0.0    0.4±0.0   0.68±0.0
# 1  0.55±0.07  0.09±0.14  0.45±0.11
# 1   0.29±0.0   0.41±0.0  0.69±0.01
# 2    0.7±0.0   0.39±0.0   0.67±0.0
# 2    0.7±0.0    0.4±0.0   0.68±0.0
# 2   0.51±0.0   0.02±0.0   0.39±0.0
# 2   0.29±0.0  0.42±0.01  0.69±0.01
# 3   0.69±0.0   0.41±0.0   0.65±0.0
# 3    0.7±0.0   0.4±0.01   0.68±0.0
# 3   0.51±0.0   0.01±0.0   0.41±0.0
# 3   0.29±0.0   0.41±0.0   0.69±0.0
